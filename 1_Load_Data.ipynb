# %% [markdown]
# ## Filter Subset: train

# %%
import requests
import json
import csv

# URL of the JSON file
url = "https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal_restaurants/filter_all_t.json"

# Send a GET request to the URL to fetch the JSON data
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON data
    json_data = json.loads(response.text)['train']
    
    # Extract the keys (assuming JSON data is in the form of a list of dictionaries)
    keys = json_data[0].keys()
    
    # Path to save the CSV file
    csv_file_path = "data_train.csv"
    
    # Write the JSON data to a CSV file
    with open(csv_file_path, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=keys)
        
        # Write the header
        writer.writeheader()
        
        # Write the rows
        for data in json_data:
            writer.writerow(data)
    
    print("CSV file saved successfully!")
else:
    # If the request was unsuccessful, print an error message
    print("Failed to fetch data from the URL:", response.status_code)
# Out:
# CSV file saved successfully!

# %%
import pandas as pd
df_train = pd.read_csv('data_train.csv')
df_train
# Out:
#                     business_id                user_id  rating  \
# 0      60567465d335d0abfb415b26  101074926318992653684       4
# 1      6050fa9f5b4ccec8d5cae994  117065749986299237881       5
# 2      604be10877e81aaed3cc9a1e  106700937793048450809       4
# 3      60411e017cd8bf130362365a  101643045857250355161       5
# 4      604139dd7cd8bf1303624208  109802745326785766951       4
# ...                         ...                    ...     ...
# 87008  604bad2d20f26f37fb9d7db0  116424268004501507050       3
# 87009  60417f132e57ebdea29c4b80  117588849143422747708       5
# 87010  6055c4233019cb0a47838a63  105232116717227512438       4
# 87011  60509067c53d98b3eace16a7  111963502676898067823       5
# 87012  6056525597d555cc6fb0d20d  101963057332995316159       5
#
#                                              review_text  \
# 0      The tang of the tomato sauce is outstanding. A...
# 1                  Chicken and waffles were really good!
# ...

# %%
# History review of user_id = 101074926318992653684 to different business_id
df_train['history_reviews'][0]
# Out:
# '[[\'101074926318992653684_6056272797d555cc6fb0d147\', \'The pizza here is the real deal, perfect in every way except for the crust, which was more cracker crisp than chewy bread. Also recommend the meatball parmigiana hero, beefy, fluffy, overflowing, tangy, chunky tomato sauce, toothsome bread.\'], [\'101074926318992653684_604a65c2c6dc737bce7e5a3d\', \'Omg the tomato sauce is everything, in the meatball appetizer, pizza & as a dip for that scratch-made focaccia. Farm-fresh salad. A variety of artisan toppings. Ask for the chili oil! Goes great with the focaccia bread.\'], [\'101074926318992653684_60433b8d8be5d4454df9cc51\', \'First time around last year, we stuck to eggs and Benedict, which were okay not outstanding. Ours included bleskiver, a delightful Danish pancake donut, crepe, and potato pancake with German sausage. The bleskiver is fluffy yet yeasty but not too sweet.\'], [\'101074926318992653684_6055ebe4f69c7b117806fdaa\', \'Food was lukewarm, including fried calamari.\'], 
# ...

# %% [markdown]
# ## Filter Subset: validation

# %%
# URL of the JSON file
url = "https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal_restaurants/filter_all_t.json"

# Send a GET request to the URL to fetch the JSON data
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON data
    json_data = json.loads(response.text)['val']
    
    # Extract the keys (assuming JSON data is in the form of a list of dictionaries)
    keys = json_data[0].keys()
    
    # Path to save the CSV file
    csv_file_path = "data_val.csv"
    
    # Write the JSON data to a CSV file
    with open(csv_file_path, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=keys)
        
        # Write the header
        writer.writeheader()
        
        # Write the rows
        for data in json_data:
            writer.writerow(data)
    
    print("CSV file saved successfully!")
else:
    # If the request was unsuccessful, print an error message
    print("Failed to fetch data from the URL:", response.status_code)
# Out:
# CSV file saved successfully!

# %%
df_val = pd.read_csv('data_val.csv')
df_val
# Out:
#                     business_id                user_id  rating  \
# 0      6049974fb1a0aaee3eefb0dd  112777069092124620875       5
# 1      6040f95d7cd8bf1303622198  116435353904842843088       5
# 2      60521c38d8c08f462b93e849  108930124171149144574       4
# 3      605440914c439864897ed9df  105287034927846928048       5
# 4      6050c60f5b4ccec8d5cae83e  112960187280808873275       5
# ...                         ...                    ...     ...
# 10855  60416ef12e57ebdea29c43ea  109535394381266525122       5
# 10856  6050f768c53d98b3eace193d  116660163645292334931       5
# 10857  604720936f0b398c7116c5d3  114494880006135486241       5
# 10858  605331f811a96a1e3740a65d  110204697034501773042       4
# 10859  604e840f7ce15821f3975034  103307219276790629050       5
#
#                                              review_text  \
# 0      It's really the best hot chicken I've had anyw...
# 1      The omelettes are really good but come hungry ...
# ...

# %% [markdown]
# ## Filter Subset: test

# %%
# URL of the JSON file
url = "https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal_restaurants/filter_all_t.json"

# Send a GET request to the URL to fetch the JSON data
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON data
    json_data = json.loads(response.text)['test']
    
    # Extract the keys (assuming JSON data is in the form of a list of dictionaries)
    keys = json_data[0].keys()
    
    # Path to save the CSV file
    csv_file_path = "data_test.csv"
    
    # Write the JSON data to a CSV file
    with open(csv_file_path, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=keys)
        
        # Write the header
        writer.writeheader()
        
        # Write the rows
        for data in json_data:
            writer.writerow(data)
    
    print("CSV file saved successfully!")
else:
    # If the request was unsuccessful, print an error message
    print("Failed to fetch data from the URL:", response.status_code)
# Out:
# CSV file saved successfully!

# %%
df_test = pd.read_csv('data_test.csv')
df_test
# Out:
#                     business_id                user_id  rating  \
# 0      604bf6a75041fa50c4bce594  108919790647235091207       5
# 1      604ee8b388c7af3f893e613b  108111397722253060630       5
# 2      605121e75b4ccec8d5caea76  114961509003938009497       5
# 3      6050d2cf9c93e55e75b72260  108970514621946615447       5
# 4      6046315010ec061e056b3f81  113922271624881467869       4
# ...                         ...                    ...     ...
# 11010  6040b07cc6fcf1fddba0dfd5  117829863369063969255       5
# 11011  6056b2c9f69c7b1178070109  107024884024793098757       5
# 11012  604ad57db1a0aaee3eefbead  102202511962268105684       2
# 11013  605026f90f8302d2f838676d  102279422150937367692       5
# 11014  6042f5ed9b00092d7286a9a5  113282555457834301884       5
#
#                                              review_text  \
# 0      This was my first time having sushi and I defi...
# 1             I tried the spicy 'Nashville Hot Chicken'.
# ...

# %% [markdown]
# ## Image Review All

# %%
import requests
import json
import csv

# URL of the JSON file
url = "https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal_restaurants/image_review_all.json"

# Send a GET request to the URL to fetch the JSON data
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Split the response text into individual JSON objects or arrays
    json_data_list = response.text.split('\n')  # Change '\n' to appropriate delimiter if needed

    # Extract the keys (assuming JSON data is in the form of a list of dictionaries)
    keys = json.loads(json_data_list[0]).keys()
    
    # Path to save the CSV file
    csv_file_path = "data_all.csv"
    
    # Write the JSON data to a CSV file
    with open(csv_file_path, 'w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=keys)
        
        # Write the header
        writer.writeheader()
        
        # Write the rows
        for json_data in json_data_list:
            if json_data.strip():  # Check if JSON data is not empty
                # Parse the JSON data
                data_dict = json.loads(json_data)
                
                # Write the row
                writer.writerow(data_dict)
    
    print("CSV file saved successfully!")
else:
    # If the request was unsuccessful, print an error message
    print("Failed to fetch data from the URL:", response.status_code)
# Out:
# CSV file saved successfully!

# %%
df_all = pd.read_csv('data_all.csv')
df_all
# Out:
#                       business_id                user_id  rating  \
# 0        605730f68cd0e3d69a52284b  113890892872599852766       4
# 1        605730f68cd0e3d69a52284b  100158382312395993536       5
# 2        605730f68cd0e3d69a52284b  113495161718980109602       2
# 3        605730f68cd0e3d69a52284b  111259544401075262963       3
# 4        605730f68cd0e3d69a52284b  104285463275063919410       5
# ...                           ...                    ...     ...
# 1487742  60401a5466e8bd764351f091  107790040475008770577       5
# 1487743  60401a5466e8bd764351f091  102318676431181796476       5
# 1487744  60401a5466e8bd764351f091  115604769413521307669       4
# 1487745  60401a5466e8bd764351f091  101315114581473619145       4
# 1487746  60401a5466e8bd764351f091  116057206044139721905       5
#
#                                                review_text  \
# 0        We came for a birthday brunch and this place i...
# 1        Cool place to hang out, have drinks.  There is...
# ...
